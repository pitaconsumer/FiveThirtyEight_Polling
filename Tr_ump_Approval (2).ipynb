# %%
#Selecting Five-Thiry-Eight Dataset to run Data Visualization Module
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Part 1

# %%
#Part 1 Loading an example dataset with 4 continuous variables and 1 categorical variable provided by the seaborn package.

FiveThirtyEight_file =  '/Users/mehrunisaqayyum/Downloads/approval_polllist.csv'
df = pd.read_csv(FiveThirtyEight_file)
df.head()
# Out:
#       president   subgroup  modeldate  startdate    enddate  \
# 0  Donald Trump  All polls  2/20/2020  1/20/2017  1/22/2017
# 1  Donald Trump  All polls  2/20/2020  1/20/2017  1/22/2017
# 2  Donald Trump  All polls  2/20/2020  1/20/2017  1/24/2017
# 3  Donald Trump  All polls  2/20/2020  1/21/2017  1/23/2017
# 4  Donald Trump  All polls  2/20/2020  1/20/2017  1/25/2017
#
#                 pollster grade  samplesize population    weight  ...  \
# 0                 Gallup     B      1500.0          a  0.241682  ...
# 1        Morning Consult   B/C      1992.0         rv  0.696984  ...
# 2                  Ipsos    B-      1632.0          a  0.150785  ...
# 3                 Gallup     B      1500.0          a  0.223234  ...
# 4  Quinnipiac University    B+      1190.0         rv  1.494494  ...
#
#    disapprove  adjusted_approve  adjusted_disapprove  multiversions  tracking  \
# 0        45.0         45.721305            43.580424            NaN         T
# ...

# %% [markdown]
# ##Q1: 1 Variable

# %% [markdown]
#  ###First Way: Histogram of Adjusted Approval Rating of Drumpf

# %%
#Choose one variable and plot that variable four different ways.
# Creating variables for each of the four conditions to graph using the basic matplotlib functionality. 

plt.hist(df["adjusted_approve"], color='red',  alpha=.5,label='Approval')  # alpha just controls the opacity
plt.xlabel('Drumpf Approval')
plt.legend(loc='upper right')
plt.title('Plot 1: Drump Adjusted Approval Rating')
plt.show()

# %% [markdown]
# ###Second Way: Line Plot of Adjusted Approval Rating of Drumpf

# %%
# %matplotlib inline
plt.plot(df["adjusted_approve"], color='pink',)
plt.xlabel('Drumpf Approval')
plt.title('Plot 2: Drump Adjusted Approval Rating')
plt.show()

# %% [markdown]
# ###Third Way: Scatterplot of Adjusted Approval Rating of Drumpf

# %%
plt.scatter(x=df['adjusted_approve'],y=df['approve'])
plt.xlabel('Drumpf Approval')
plt.title('Plot 3: Drump Adjusted Approval Rating')
plt.show()

# %% [markdown]
# ###Fourth Way: Boxplot of Adjusted Approval Rating of Drumpf

# %%
# Generate and display the box plot.
# Set the random seed to keep the example consistent.
np.random.seed()

# Sample data.
x = np.random.normal()
plt.boxplot('adjusted_approve')
plt.xlabel('Drumpf Approval')
plt.title('Plot 4: Drump Adjusted Approval Rating')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-c70e42f7db18> in <module>
#       5 # Sample data.
#       6 x = np.random.normal()
# ----> 7 plt.boxplot('adjusted_approve')
#       8 plt.xlabel('Drumpf Approval')
#       9 plt.title('Plot 4: Drump Adjusted Approval Rating')
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2477         whiskerprops=whiskerprops, manage_ticks=manage_ticks,
#    2478         autorange=autorange, zorder=zorder, **({"data": data} if data
# -> 2479         is not None else {}))
#    2480
#    2481
#
# ...

# %% [markdown]
# ##Part 1, Q2: Choose two continuous variables, and plot them three different ways.

# %%
#Selecting "adjusted_approve" and "adjusted_disaprove" || Note categorical is "grade"
g = sns.lmplot(y='adjusted_approve', # Variable 1.
               x='adjusted_disapprove', # Variable 2.
               data=df, # Data
               fit_reg=False, # If set to true, plots a regression line.
               scatter_kws={'alpha':0.4}) # Set points to semi-transparent to see overlapping points.
g.set_ylabels("Approve")
g.set_xlabels("Disapprove")
plt.title('Plot1: Scatterplot of Drumpf Disapproval')
plt.show()

g = sns.lmplot(y='adjusted_disapprove', 
               x='adjusted_approve',
               data=df, # Data.
               fit_reg=True, # The regression line also includes a 95% confidence envelope.
               scatter_kws={'alpha':0.4})
g.set_ylabels("adjusted_disapprove")
g.set_xlabels("adjusted_approve")
plt.title('Plot 2: Scatterplot with regression line: Drumpf Disapproval')
plt.show()

# %%
plt.plot(df['adjusted_approve'], color='purple')
plt.plot(df['adjusted_disapprove'], color='pink')
plt.ylim()
plt.ylabel('Score')
plt.title('Plot 3: Drump Adjusted Approval Rating')
plt.show()

# %%
#Choose two continuous variables, and plot them three different ways.
#Chose Approve and Disapprove
print(df.head())
df.columns
g = sns.lmplot(y='approve', # Variable 1.
               x='disapprove', # Variable 2.                
               data= df, # Data
           fit_reg=True, # If set to true, plots a regression line.
           scatter_kws={'alpha':0.4}) # Set points to semi-transparent to see overlapping points.
g.set_ylabels("approve")
g.set_xlabels("disapprove")
plt.title('Scatterplot: Approval of Trump Performance')
plt.show()
# Out:
#       president   subgroup  modeldate  startdate    enddate  \
# 0  Donald Trump  All polls  2/20/2020  1/20/2017  1/22/2017
# 1  Donald Trump  All polls  2/20/2020  1/20/2017  1/22/2017
# 2  Donald Trump  All polls  2/20/2020  1/20/2017  1/24/2017
# 3  Donald Trump  All polls  2/20/2020  1/21/2017  1/23/2017
# 4  Donald Trump  All polls  2/20/2020  1/20/2017  1/25/2017
#
#                 pollster grade  samplesize population    weight  ...  \
# 0                 Gallup     B      1500.0          a  0.241682  ...
# 1        Morning Consult   B/C      1992.0         rv  0.696984  ...
# 2                  Ipsos    B-      1632.0          a  0.150785  ...
# 3                 Gallup     B      1500.0          a  0.223234  ...
# 4  Quinnipiac University    B+      1190.0         rv  1.494494  ...
#
#    disapprove  adjusted_approve  adjusted_disapprove  multiversions  tracking  \
# 0        45.0         45.721305            43.580424            NaN         T
# ...

# %% [markdown]
# ## Part 1, Q3: Choose one continuous variable and one categorical variable, and plot them six different ways.

# %%
###First Way: Histogram of Drumpf Approval Rating and Grade

# %%
#1st Way continuous is approval, categorical is 'grade'

# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist("approve", bins=40, color='purple')
plt.hist("grade", bins=40, color='pink')
plt.title('Plot 1: Drump Approval Rating')
plt.xlabel('Random Values')
plt.show()

# %% [markdown]
# ##Optional Second Way: Barplot

# %%
import seaborn as sns
# %matplotlib inline 

df =sns.load_dataset('FiveThirtyEight_file')
sns.barplot(x='approve',y='grade',data=df)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-158-8aa1a7ab4b4b> in <module>
#       2 get_ipython().run_line_magic('matplotlib', 'inline ')
#       3
# ----> 4 df =sns.load_dataset('FiveThirtyEight_file')
#       5 sns.barplot(x='approve',y='grade',data=df)
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# /opt/anaconda3/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ...

# %%
#df['grade'] = df['FiveThirtyEight_file'].astype('string', errors='ignore')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FiveThirtyEight_file'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-135-9488694b5f26> in <module>
# ...

# %%
# Data to play with. Twice the histograms, twice the fun.
#x = df["approve"]
#y = df["grade"]

# Override bin defaults with specific bin bounds.
# FYI `alpha` controls the opacity.
#df['grade'] = df['FiveThirtyEight_file'].astype('string', errors='ignore')
#plt.hist(x, color='blue', bins=np.arange(-10, 40), alpha=.5) 
#plt.hist(y, color='red', bins=np.arange(-10, 40), alpha=.5)
#plt.title('Manually setting bin placement')
#plt.xlabel('Random Values')

#plt.show()

# %% [markdown]
# ###Optional Third Way: Scatter of Drumpf Adjusted Approval Rating

# %%
plt.scatter(x=df['adjusted_approve'],y=df['grade'])
plt.xlabel('Drumpf Approval')
plt.title('Plot 3: Drumpf Adjusted Approval Rating')
plt.show()

#plt.hist(df["approve"], color='red',  alpha=.5,label='Approval')
#plt.xlabel('Drumpf Approval')
#plt.ylabel('Grade')
#plt.legend(loc='upper right')
#plt.title('Plot 3: Drump Approval Rating')
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-97f24f549db4> in <module>
# ----> 1 plt.scatter(x=df['adjusted_approve'],y=df['grade'])
#       2 plt.xlabel('Drumpf Approval')
#       3 plt.title('Plot 2: Drumpf Adjusted Approval Rating')
#       4 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
# ...

# %% [markdown]
# ##Choose two continuous variables, and plot them three different ways.

# %%
#Chose Approve and Disapprove
print(df.head())
df.columns
g = sns.lmplot(y='approve', # Variable 1.
               x='disapprove', # Variable 2.                
               data= df, # Data
           fit_reg=True, # If set to true, plots a regression line.
           scatter_kws={'alpha':0.4}) # Set points to semi-transparent to see overlapping points.
g.set_ylabels("approve")
g.set_xlabels("disapprove")
plt.title('Scatterplot: Disapproval of Trump Performance')
plt.show()
# Out:
#       president   subgroup  modeldate  startdate    enddate  \
# 0  Donald Trump  All polls  2/20/2020  1/20/2017  1/22/2017
# 1  Donald Trump  All polls  2/20/2020  1/20/2017  1/22/2017
# 2  Donald Trump  All polls  2/20/2020  1/20/2017  1/24/2017
# 3  Donald Trump  All polls  2/20/2020  1/21/2017  1/23/2017
# 4  Donald Trump  All polls  2/20/2020  1/20/2017  1/25/2017
#
#                 pollster grade  samplesize population    weight  ...  \
# 0                 Gallup     B      1500.0          a  0.241682  ...
# 1        Morning Consult   B/C      1992.0         rv  0.696984  ...
# 2                  Ipsos    B-      1632.0          a  0.150785  ...
# 3                 Gallup     B      1500.0          a  0.223234  ...
# 4  Quinnipiac University    B+      1190.0         rv  1.494494  ...
#
#    disapprove  adjusted_approve  adjusted_disapprove  multiversions  tracking  \
# 0        45.0         45.721305            43.580424            NaN         T
# ...

# %% [markdown]
# ###Third Way:

# %%
plt.plot(df['approve'], color='purple')
plt.plot(df['disapprove'], color='pink')
plt.ylim()
plt.ylabel('Score')
plt.title('Plot 3: Drump Approval Rating')
plt.show()

# %% [markdown]
# ###Second Way: Catplot

# %%
#Seaborns
sns.set(style="darkgrid")

# Use catplot (previous versions of seaborn use factorplot)
g = sns.catplot(y="adjusted_approve", x="grade", hue="grade", data=df,
                   height=6, kind="bar", palette="pastel", ci=95)
g.despine(left=True)
g.set_ylabels("adjusted_approve")
g.set_xlabels("grade")
plt.title('Barplot: Drumpf Adjusted Approval Rating')
plt.show()

# %% [markdown]
# ###Third Way: Countplot

# %%
#sns.countplot(x='sex',data=t)
import seaborn as sns
# %matplotlib inline 
df =sns.load_dataset((pd.read_csv('FiveThirtyEight_file)'))
#to check some rows to get a idea of the data present
df.head()
# Out:
#   File "<ipython-input-163-da1b19866215>", line 6
#     df.head()
#      ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)
#sns.set(style="ticks")
df = sns.load_dataset("FiveThirtyEight_file")
g = sns.relplot(x="grade", y="adjusted_approve", hue="grade", data=df)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-160-e19e4bafd198> in <module>
#       3 sns.set(style="ticks", color_codes=True)
#       4 #sns.set(style="ticks")
# ----> 5 df = sns.load_dataset("FiveThirtyEight_file")
#       6 g = sns.relplot(x="grade", y="adjusted_approve", hue="grade", data=df)
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# /opt/anaconda3/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
# ...

# %% [markdown]
# ###Fourth Way: Relplot

# %%
#Replicating this example
#import seaborn as sns
#sns.set(style="ticks")
#tips = sns.load_dataset("tips")
#g = sns.relplot(x="grade", y="adjusted_approve", hue="grade", data=df)
import seaborn as sns
df2 = sns.load_dataset('df')
g = sns.relplot(x="grade", y="adjusted_approve",
                hue="grade", style="", col="region",
                kind="line", data=df)

# %% [markdown]
# ###Fifth Way: Boxplot

# %%
#Replicating
#sns.boxplot(x='grade',y='adjusted_approve',data=df,palette='rainbow')

# %% [markdown]
# ###Sixth Way: Violin Plot

# %%
#Replicating
#sns.violinplot(x="grade", y="adjusted_approve", data=df,palette='rainbow')

# %% [markdown]
# ###Give the pros and cons of each plot you create. You can use variables from multiple datasets if you like.
# ####1) In Barplot: The bar has to start at '0'
# ####2)

# %% [markdown]
# ##Part 2, Q1: four continuous variables and one categorical variable

# %%
#Categorical variable is 'pollster'; continues variables are 'approve', "adjusted_approve", disapprove, "adjusted_disapprove"
df = sns.load_dataset("FiveThirtyEight_file")
sns.catplot(x="pollster", y="approve", data=df);

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])
